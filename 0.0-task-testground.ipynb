# %%
# We will load all required modules first.
try:
    from dstaster import *
except:
    # !pip install wget

    import wget
    url = 'https://raw.githubusercontent.com/BBKdatasciencetaster/DS/main/dstaster.py'
    wget.download(url)
    from dstaster import *

# %%
print("Test")








print("Yes")
# Out:
# Test
# Yes

# %%
print("This output should be visible")
error("Something went wrong",
      "Here is an idea of how to fix it")

print("This output should not be visible")
# Out:
# This output should be visible
#         <div class="error">
#             <div class="title"><b>Error:</b> Something went wrong</div>
#             <div class="msg">Here is an idea of how to fix it</div>
#         </div>

# %% [markdown]
# This is a normal paragraph.
#
# <div class="note">This is side note that provides some background information that might not be interesting to everyone.</div>
#
# <div class="task">
#     <div class="no">1</div>
#     <div class="text">
#         This is a task for our students, explaining what to do
#         in the following code cell. <br/>
#         Here is another line. <br/>
#         And another.
#     </div>
# </div>
#
# <div class="task">
#     <div class="no">2</div>
#     <div class="text">
#         This is task with a short text.
#     </div>
# </div>
#
#
# <div class="task">
#     <div class="no">12</div>
#     <div class="text">
#         This is task with a short text.
#     </div>
# </div>
#
# <ol class="hints">
#     <li>
#         <div>This is a first hint. <br/> It has two lines.
#         </div>
#     </li>
#     <li>
#         <div>This is a second hint. </div>
#     </li>
#     <li>
#         <div>This is a third hint. </div>
#     </li>
# </ol>

# %% [markdown]
# <ol class="hints">
#     <li>
#         <div>This is a first hint. <br/> It has two lines.
#         </div>
#     </li>
#     <li>
#         <div>This is a second hint. </div>
#     </li>
#     <li>
#         <div>This is a third hint. </div>
#     </li>
# </ol>

# %%
# Test default color cycling
fig, ax = plt.subplots(dpi=300, figsize=(7,3))

for i in range(8):
    xs = np.linspace(0,10,50)
    ys = np.sin(xs)+i
    ax.plot(xs, ys)

# %%
config = {
    'value': 'pineapple',
    'description': 'Metric test'
}

layout = {
    'width': '100%',
}

widgets.RadioButtons(
    options=['pepperoni', 'pineapple', 'anchovies'],
    layout=layout,
    **config
)
# Out:
# RadioButtons(description='Metric test', index=1, layout=Layout(width='100%'), options=('pepperoni', 'pineapple…

# %%
config = {
    'continuous_update': False,
    'min': 1,
    'value': 10,
    'max': 100
}

layout = {
    'width': '70%',
}
widgets.IntSlider(**config, layout=layout, description="Bin size")
# Out:
# IntSlider(value=10, continuous_update=False, description='Bin size', layout=Layout(width='70%'), min=1)
